# %% [markdown]
# # DATA PREPROCESSING USING THE EMPLOYEE DATASET.
# 1. Load the data into the pandas environment and identify some basic details of the
# dataset.
# 2. Reset the index as "name" as the index.
# 3. Select rows for specific names Jack Morgan and Josh wills.
# 4. Select data for multiple values "Sales" and “Finance”.
# 5. Display employee who has more than 700 performance score.
# 6. Display employee who has more than 500 and less than 700 performance score
# 7. Check and handle missing values in the dataset.
# 8. Check the outliers and handle outliers in performance score using Percentiles.
# 9. Check the gender column and do Dummy encoding.
# 10.Do the standard scaling on the feature performance score

# %% [markdown]
# # 1. Load the data into the pandas environment and identify some basic details of the
# dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df=pd.read_csv('employee.csv')
df
# Out:
#             name   age   income gender  department grade  performance_score
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3                723
# 1        S Kumar   NaN  16000.0      F     Finance    G0                520
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2                674
# 3      Ying Chin  45.0  65000.0      F       Sales    G3                556
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# 5  Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# 6   James Authur  54.0      NaN      F  Operations    G3                 53
# 7     Josh Wills  54.0  52000.0      F     Finance    G3                901
# 8       Leo Duck  23.0  98000.0      M       Sales    G4                709

# %%
df.shape
# Out:
# (9, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9 non-null      object
#  1   age                7 non-null      float64
#  2   income             7 non-null      float64
#  3   gender             7 non-null      object
#  4   department         9 non-null      object
#  5   grade              9 non-null      object
#  6   performance_score  9 non-null      int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 632.0+ bytes

# %%
df.isna().sum()
# Out:
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %% [markdown]
# # 2. Reset the index as "name" as the index.

# %%
df.set_index(['name'], inplace=True)

# %%
df
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar         NaN  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# James Authur   54.0      NaN      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# # 3) Select rows for specific names Jack Morgan and Josh wills

# %%
df.loc[['Jack Morgan','Josh Wills'],:]
# Out:
#               age   income gender department grade  performance_score
# name
# Jack Morgan  32.0  35000.0      M    Finance    G2                674
# Josh Wills   54.0  52000.0      F    Finance    G3                901

# %% [markdown]
# # 4) Select data for multiple values "Sales" and “Finance”.

# %%
df[df['department'].isin(['Sales', 'Finance'])]
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649
# Josh Wills     54.0  52000.0      F    Finance    G3                901
# Leo Duck       23.0  98000.0      M      Sales    G4                709

# %% [markdown]
# # 5) Display employee who has more than 700 performance score.

# %%
df[df['performance_score']>700]
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# # 6) Display employee who has more than 500 and less than 700 performance score

# %%
df[(df['performance_score']>500) & (df['performance_score']<700)]
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649

# %% [markdown]
# # 7)Check and handle missing values in the dataset.

# %%
df.dtypes
# Out:
# age                  float64
# income               float64
# gender                object
# department            object
# grade                 object
# performance_score      int64
# dtype: object

# %% [markdown]
# # handling missing value in gender

# %%
df["gender"].fillna("Nill", inplace = True)

# %%
df
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN   Nill  Operations    G3                723
# S Kumar         NaN  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma   NaN  62000.0   Nill       Sales    G3                649
# James Authur   54.0      NaN      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# # handling missing value in age and income with median

# %%
for i in ['age','income']:
    df[i]=df[i].fillna(df[i].median())
df.isna().sum()
# Out:
# age                  0
# income               0
# gender               0
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %%
df
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0  52000.0   Nill  Operations    G3                723
# S Kumar        45.0  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma  45.0  62000.0   Nill       Sales    G3                649
# James Authur   54.0  52000.0      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# # handling missing value in age and income with mean

# %%
for i in ['age','income']:
    df[i]=df[i].fillna(df[i].mean())
df.isna().sum()
# Out:
# age                  0
# income               0
# gender               0
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %%
df
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0  52000.0   Nill  Operations    G3                723
# S Kumar        45.0  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma  45.0  62000.0   Nill       Sales    G3                649
# James Authur   54.0  52000.0      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# # 8) Check the outliers and handle outliers in performance score using Percentiles.

# %%
plt.boxplot(df['performance_score'])
plt.title('box plot of performance score')
# Out:
# Text(0.5, 1.0, 'box plot of performance score')

# %%
Q1=np.percentile(df['performance_score'],25,interpolation='midpoint')
Q2=np.percentile(df['performance_score'],50,interpolation='midpoint')
Q3=np.percentile(df['performance_score'],75,interpolation='midpoint')
print('Q1=',Q1)
print('Q2=',Q2)
print('Q3=',Q3)
# Out:
# Q1= 556.0
# Q2= 674.0
# Q3= 711.0

# %%
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
upp_lim=Q3+1.5*IQR
print(low_lim)
print(upp_lim)
# Out:
# 323.5
# 943.5

# %%
outlier=[]
for x in df['performance_score']:
    if((x>upp_lim) or (x<low_lim)):
        outlier.append(x)
outlier
# Out:
# [53]

# %%
ind1=df['performance_score']<low_lim
df.loc[ind1].index
# Out:
# Index(['James Authur'], dtype='object', name='name')

# %%
df.drop(['James Authur'],inplace=True)
df
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0  52000.0   Nill  Operations    G3                723
# S Kumar        45.0  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma  45.0  62000.0   Nill       Sales    G3                649
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# outlier is removed.

# %%
plt.boxplot(df['performance_score'])
plt.title('box plot of performance score')
# Out:
# Text(0.5, 1.0, 'box plot of performance score')

# %% [markdown]
# # 8)Check the gender column and do Dummy encoding.

# %%
df1 = pd.get_dummies(df['gender'])
df1
# Out:
#                F  M  Nill
# name
# Allen Smith    0  0     1
# S Kumar        1  0     0
# Jack Morgan    0  1     0
# Ying Chin      1  0     0
# Dheeraj Patel  1  0     0
# Satyam Sharma  0  0     1
# Josh Wills     1  0     0
# Leo Duck       0  1     0

# %%
df2=pd.concat([df,df1],axis='columns')
df2
# Out:
#                 age   income gender  department grade  performance_score  F  \
# name
# Allen Smith    45.0  52000.0   Nill  Operations    G3                723  0
# S Kumar        45.0  16000.0      F     Finance    G0                520  1
# Jack Morgan    32.0  35000.0      M     Finance    G2                674  0
# Ying Chin      45.0  65000.0      F       Sales    G3                556  1
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711  1
# Satyam Sharma  45.0  62000.0   Nill       Sales    G3                649  0
# Josh Wills     54.0  52000.0      F     Finance    G3                901  1
# Leo Duck       23.0  98000.0      M       Sales    G4                709  0
#
#                M  Nill
# name
# Allen Smith    0     1
# S Kumar        0     0
# Jack Morgan    1     0
# Ying Chin      0     0
# Dheeraj Patel  0     0
# Satyam Sharma  0     1
# Josh Wills     0     0
# Leo Duck       1     0

# %% [markdown]
# # 10)Do the standard scaling on the feature performance score

# %%
df.columns
# Out:
# Index(['age', 'income', 'gender', 'department', 'grade', 'performance_score'], dtype='object')

# %%
x=df.drop(['age', 'income', 'gender','department', 'grade'], axis=1)

# %%
x.describe()
# Out:
#        performance_score
# count            8.00000
# mean           680.37500
# std            116.16729
# min            520.00000
# 25%            625.75000
# 50%            691.50000
# 75%            714.00000
# max            901.00000

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn import preprocessing
standardisation=preprocessing.StandardScaler()
x=standardisation.fit_transform(x)
x=pd.DataFrame(x)
x.describe()
# Out:
#                   0
# count  8.000000e+00
# mean   4.857226e-17
# std    1.069045e+00
# min   -1.475872e+00
# 25%   -5.026938e-01
# 50%    1.023793e-01
# 75%    3.094385e-01
# max    2.030331e+00

# %% [markdown]
# after standard scaling, standard deviation equal to 1.
